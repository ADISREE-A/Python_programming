# %% [markdown]
# <a href="https://colab.research.google.com/github/ADISREE-A/Python_programming/blob/main/python_programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.email "adisreea2005@gmail.com"
# !git config --global user.name "ADISREE_A"

# %%
# !git clone https://github.com/ADISREE-A/Python_programming.git
# %cd Python_programming
# Out:
# Cloning into 'Python_programming'...
# warning: You appear to have cloned an empty repository.
# /content/Python_programming/Python_programming

# %%
#!git init
#!git add .
#!git commit -m "first commit"
# !git branch -M main
#!git remote add origin https://github.com/ADISREE-A/Python_programming.git
#!git push -u origin main

# %% [markdown]
# 1/6/26

# %%
#codeforces 4a-watermelon
w=int(input())
if w%2!=0 or w==2:
    print("NO")
else:
    print("YES")
""" x=w//2
    if x%2==0:
        print("(x,x)")
    else:
        print("(x-1,x+1)")"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4207/1319999679.py in <cell line: 0>()
# ----> 1 w=int(input())
#       2 if w%2!=0 or w==2:
#       3     print("NO")
#       4 else:
#       5     print("YES")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#codeforces 617a-elephant
#output is no. of steps
x=int(input())
if x<5:
    print("1")
elif x%5==0:
    print(x//5)
else:
    print(x//5+1)

# %%
#791a
limak,bob=map(int,input().split())
year=0
while limak<=bob:
    limak*=3
    bob*=2
    year+=1
print(year)

# %%
#466a
#n->total no. of travels
#m->no. of travels available using special ticket
#a-cost for normal ticket
#b cost for specil ticket
n,m,a,b=map(int,input().split())
if a*m<b:#check if cost of special ticket or normal ticket is cheap(here normal cheap)
    print(a*n)# all day travelled using special ticket only
else:
    print((n//m)*b+min(b,(n%m)*a))#special tickets cost+for remaining day calculate cost and which cost less is choosen
# Out:
# 6 2 1 2
# 6

# %% [markdown]
# 2/6/26

# %%
#removing duplicate value
l=list(map(str,input().split()))
l1=[]
for ele in l:
    if ele not in l1:
        l1.append(ele)
print(l1)
# Out:
# 11 1 1 1 2 2 2 3 3 3
# ['11', '1', '2', '3']

# %%
#no. of occurence odd and no duplicate
l=list(map(int,input().split()))
res=[]
for ele in l:
    if l.count(ele)%2!=0 and ele not in res:
        res.append(ele)
print(res)
# Out:
# 4 2 2 5 6 3 2
# [4, 2, 5, 6, 3]

# %%
#even no. in desc and odd no. in asc ip:2 5 7 9 6 1 op:[6,2,1,5,7,9]
l=list(map(int,input().split()))
l.sort()
res=[]
for ele in l:
     if ele%2!=0:
        res.append(ele)
     else:
        res.insert(0,ele)
print(res)
# Out:
# 2 5 7 9 6 1
# [6, 2, 1, 5, 7, 9]

# %%
#427a
n=int(input())
police,unsolved=0,0
event=list(map(int,input().split()))
for e in event:
    if e==-1:#
        if police>0:
            police-=1
        else:
            unsolved+=1
    else:
        police+=e
print(unsolved)
